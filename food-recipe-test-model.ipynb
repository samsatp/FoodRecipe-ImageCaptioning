# %%
from cnnattn_model import *
import tensorflow as tf
import json

image_folder_dir = "../input/foodrecipe/"
tf.__version__
# Out:
# '2.4.1'

# %%
image_path = json.load(open("../input/foodrecipe/image_path.json", "r"))
recipe_string = json.load(open("../input/foodrecipe/data_strings_local.json", "r"))

# %% [markdown]
# # Preprocess the data

# %%
import re

recipe_joined = {}

for recipe, steps in recipe_string.items():
    steps_joined = "<START> "
    for i in range(len(steps)):
        step_i = steps[i].strip()
        if step_i[-1] == ".": 
            step_i = step_i[:-1] + " <SEP> "
        steps_joined += step_i
    
        
    recipe_joined[recipe] = steps_joined[:-7] + " <END>"

# %%
text = []
images = []
menu_names =[]
not_having_image = []

for menu, steps in recipe_joined.items():
    
    try:
        paths = image_path[menu]
    except KeyError as e:
        not_having_image.append(menu)
        continue
    
    for path in paths:
        menu_names.append(menu)
        text.append(steps)
        images.append(image_folder_dir+path)

# %%
assert len(images) == len(text)
not_having_image
# Out:
# ['Eggless_Strawberry_Cupcakes_with_Pink_Strawberry_Buttercream_Frosting',
#  'Homemade_Lychee_Kulfi',
#  'Stenciled_Christmas_Sugar_Cookies_Video_Tutorial',
#  'Chicken_and_Broccoli_Zucchini_Noodle_Stir_Fry']

# %%
print(menu_names[0])
print(text[0])
# Out:
# Cream_Cheese_Strawberry_Braided_Pastry
# <START> Preheat the oven at 200 C/ 390 F <SEP> Cream cheese spread - combine all ingredients in a bowl - set aside <SEP> Roll puff pastry to a rectangle - 12 x 6-inches wide <SEP> Transfer to a parchment paper so it's easier to move to the baking tray <SEP> Mark the pastry at 1 ½" from both edges lengthways (see video) <SEP> Cut off two corners (triangles) from the top and bottom - see video <SEP> Spread a generous amount of cream cheese down the center (I prefer to use a piping bag) <SEP> Then, spread a generous amount of strawberry jam over the cream cheese mixture <SEP> Using a sharp knife or pizza wheel, cut slanting strips along both sides of the pastry <SEP> Fold both ends at the top and bottom over the filling (this will prevent the filling coming out when baking) <SEP> Braid the pastry by crossing the strips over the filling overlapping each other (see video) <SEP> When you reach the end, you can overlap any excess strips or cut them off <SEP> Pick the pastry with the parchment paper and transfer it to the baking tray <SEP> Brush the pastry with beaten egg <SEP> Bake in a preheated oven for 20 to 25 minutes, or until golden brown <SEP> Remove from the oven and let cool for at least 10 minutes- Do not try to transfer as the pastry may break and do not serve as the jam will be bubbling hot <SEP> Serve warm or room temperature <END>

# %% [markdown]
# # 1. Tokenization & Pad sequences
# `Vocab size = 1000`

# %%
vocab_size = 300
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=vocab_size, 
                                                  filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n', 
                                                  oov_token="<unk>")
tokenizer.word_index['<pad>'] = 0
tokenizer.index_word[0] = '<pad>'
tokenizer.word_index['<sep>'] = 1
tokenizer.index_word[1] = '<sep>'
tokenizer.fit_on_texts(text)

# %%
text_index = tokenizer.texts_to_sequences(text)
text_index = tf.keras.preprocessing.sequence.pad_sequences(text_index, maxlen=vocab_size, padding='post', value=0.0)

# %%
text_index
# Out:
# array([[ 56, 117,   2, ...,   0,   0,   0],
#        [ 56, 117,   2, ...,   0,   0,   0],
#        [ 56, 117,   2, ...,   0,   0,   0],
#        ...,
#        [  4, 210,   5, ...,   1,   7,  55],
#        [  4, 210,   5, ...,   1,   7,  55],
#        [  4, 210,   5, ...,   1,   7,  55]], dtype=int32)

# %% [markdown]
# # 2. Create a tf.data dataset for training
#
# Let's first preprocess the images and save them back to disk.

# %%
import numpy as np

def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, (128, 128))
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

image_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet')
new_input = image_model.input
hidden_layer = image_model.layers[-1].output

image_features_extract_model = tf.keras.Model(new_input, hidden_layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step

# %%
# Feel free to change batch_size according to your system configuration
image_dataset = tf.data.Dataset.from_tensor_slices(images)
image_dataset = image_dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

for img, path in image_dataset:
    batch_features = image_features_extract_model(img)
    batch_features = tf.reshape(batch_features,
                              (batch_features.shape[0], -1, batch_features.shape[3]))

    for bf, p in zip(batch_features, path):
        p = p.numpy().decode("utf-8")
        p = p.replace("../input/foodrecipe/images/","")
        p = p.replace(".jpg","")
        np.save(p, bf.numpy())

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 128
units = 256

# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

# %%
images_path = []

for p in images:
    p = p.replace("../input/foodrecipe/images/","")
    p = p.replace(".jpg","")
    images_path.append(p)
images_path
# Out:
# ['Cream_Cheese_Strawberry_Braided_Pastry_0',
#  'Cream_Cheese_Strawberry_Braided_Pastry_1',
#  'Cream_Cheese_Strawberry_Braided_Pastry_2',
#  'The_BEST_Thumbprint_Cookies_Eggless_Jam_Cookies_Recipe_0',
#  'The_BEST_Thumbprint_Cookies_Eggless_Jam_Cookies_Recipe_1',
#  'Bean_Paste_Recipe_for_Sugar_Flowers_or_Korean_Bean_Paste_0',
#  'Bean_Paste_Recipe_for_Sugar_Flowers_or_Korean_Bean_Paste_1',
#  'Bean_Paste_Recipe_for_Sugar_Flowers_or_Korean_Bean_Paste_2',
#  'Bean_Paste_Recipe_for_Sugar_Flowers_or_Korean_Bean_Paste_3',
#  'Bean_Paste_Recipe_for_Sugar_Flowers_or_Korean_Bean_Paste_4',
#  'Slow_Cooker_Shredded_Beef_0',
#  'Slow_Cooker_Shredded_Beef_1',
#  'Slow_Cooker_Shredded_Beef_2',
#  'Slow_Cooker_Shredded_Beef_3',
#  'Ground_Beef_Soup_0',
#  'Moist_Strawberry_Chocolate_Brownie_Recipe_0',
#  'Cherry_Cheesecake___Baked_0',
#  'Cherry_Cheesecake___Baked_1',
#  'Cherry_Cheesecake___Baked_2',
#  'Cherry_Cheesecake___Baked_3',
#  'Crock_Pot_or_Slow_Cooker_Lamb_Recipe_0',
#  'Crock_Pot_or_Slow_Cooker_Lamb_Recipe_1',
#  'Crock_Pot_or_Slow_Cooker_Lamb_Recipe_2',
#  'Crock_Pot_or_Slow_Cooker_Lamb_Recipe_3',
#  'Crock_Pot_or_Slow_Cooker_Lamb_Recipe_4',
#  'Almond_Linzer_Cookies_0',
#  'Almond_Linzer_Cookies_1',
#  'Almond_Linzer_Cookies_2',
#  'Almond_Linzer_Cookies_3',
#  'Butterscotch_Fruitcake_Recipe_0',
#  'Butterscotch_Fruitcake_Recipe_1',
#  'Butterscotch_Fruitcake_Recipe_2',
#  'Butterscotch_Fruitcake_Recipe_3',
#  'Butterscotch_Fruitcake_Recipe_4',
#  'Butterscotch_Fruitcake_Recipe_5',
#  'Hot_Chocolate_Mix_with_real_chocolate_0',
#  'Sponge_Cake___Vanilla_and_Chocolate_0',
#  'Easy_Watermelon_Lemonade_0',
#  'Easy_Watermelon_Lemonade_1',
#  'Easy_Watermelon_Lemonade_2',
#  'Sun_Dried_Tomato_Olive_Rolls_0',
#  'Sun_Dried_Tomato_Olive_Rolls_1',
#  'Sun_Dried_Tomato_Olive_Rolls_2',
#  'Sun_Dried_Tomato_Olive_Rolls_3',
#  'Lentil_Chicken_Curry_0',
#  'Lentil_Chicken_Curry_1',
#  'Lentil_Chicken_Curry_2',
#  'Carrot_Cake_with_Swiss_Meringue_Buttercream_0',
#  'Carrot_Cake_with_Swiss_Meringue_Buttercream_1',
#  'Carrot_Cake_with_Swiss_Meringue_Buttercream_2',
#  'Carrot_Cake_with_Swiss_Meringue_Buttercream_3',
#  'Homemade_Marzipan_Recipe_0',
#  'Homemade_Marzipan_Recipe_1',
#  'Homemade_Marzipan_Recipe_2',
#  'No_Churn_Dulce_De_Leche_Ice_Cream_0',
#  'No_Churn_Dulce_De_Leche_Ice_Cream_1',
#  'No_Churn_Dulce_De_Leche_Ice_Cream_2',
#  'Moist_Vanilla_Pound_Cake_0',
#  'Moist_Vanilla_Pound_Cake_1',
#  'Moist_Vanilla_Pound_Cake_2',
#  'Moist_Vanilla_Pound_Cake_3',
#  'Moist_Vanilla_Pound_Cake_4',
#  'Cinnamon_Sugar_Fried_Pumpkin_Donuts_0',
#  'Cinnamon_Sugar_Fried_Pumpkin_Donuts_1',
#  'Cinnamon_Sugar_Fried_Pumpkin_Donuts_2',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_0',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_1',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_2',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_3',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_4',
#  'Caramel_Apple_Cake_Recipe_with_Caramel_Buttercream_5',
#  'Pistachio_Halva_Hamantaschen_Cookies_0',
#  'Pistachio_Halva_Hamantaschen_Cookies_1',
#  'Cream_Cheese_Nectarine_Tart_0',
#  'Cream_Cheese_Nectarine_Tart_1',
#  'Cream_Cheese_Nectarine_Tart_2',
#  'Cream_Cheese_Nectarine_Tart_3',
#  'Easy_Chocolate_Mousse_0',
#  'Easy_Chocolate_Mousse_1',
#  'Easy_Chocolate_Mousse_2',
#  'Easy_Chocolate_Mousse_3',
#  'Instant_Pot_Split_Pea_Soup_0',
#  'Instant_Pot_Split_Pea_Soup_1',
#  'Instant_Pot_Split_Pea_Soup_2',
#  'Instant_Pot_Split_Pea_Soup_3',
#  'Spaghetti_and_Meatballs_0',
#  'Spaghetti_and_Meatballs_1',
#  'Spaghetti_and_Meatballs_2',
#  'Spaghetti_and_Meatballs_3',
#  'Roast_Potatoes_Rosemary_and_Lemon__0',
#  'Roast_Potatoes_Rosemary_and_Lemon__1',
#  'Roast_Potatoes_Rosemary_and_Lemon__2',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_0',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_1',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_2',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_3',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_4',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_5',
#  'Homemade_Edible_Sugar_Lace_Recipe_Eggless_and_Vegetarian_6',
#  'Mushroom_Masala_Restaurant_Style_0',
#  'Mushroom_Masala_Restaurant_Style_1',
#  'Mushroom_Masala_Restaurant_Style_2',
#  'Mushroom_Masala_Restaurant_Style_3',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_0',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_1',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_2',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_3',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_4',
#  'Easy_Celery_Salad_Recipe_with_Cranberries_and_Pecans_5',
#  'Turmeric_Rice_with_Chicken_and_Peas_0',
#  'Turmeric_Rice_with_Chicken_and_Peas_1',
#  'Turmeric_Rice_with_Chicken_and_Peas_2',
#  'Fresh_Tomato_Sauce___20_mins_0',
#  'Fresh_Tomato_Sauce___20_mins_1',
#  'Matcha_Macarons__Green_Tea__0',
#  'Matcha_Macarons__Green_Tea__1',
#  'Matcha_Macarons__Green_Tea__2',
#  'Matcha_Macarons__Green_Tea__3',
#  'Matcha_Macarons__Green_Tea__4',
#  'White_Cake_Recipe_0',
#  'White_Cake_Recipe_1',
#  'White_Cake_Recipe_2',
#  'White_Cake_Recipe_3',
#  'White_Cake_Recipe_4',
#  'Tuna_Potato_Patties_0',
#  'Tuna_Potato_Patties_1',
#  'Tuna_Potato_Patties_2',
#  'Tuna_Potato_Patties_3',
#  'Vanilla_Cherry_Cupcakes_0',
#  'Vanilla_Cherry_Cupcakes_1',
#  'Vanilla_Cherry_Cupcakes_2',
#  'Vanilla_Cherry_Cupcakes_3',
#  'Vanilla_Cherry_Cupcakes_4',
#  'Homemade_Cloverleaf_Rolls_0',
#  'Homemade_Cloverleaf_Rolls_1',
#  'Homemade_Cloverleaf_Rolls_2',
#  'Homemade_Cloverleaf_Rolls_3',
#  'Homemade_Cloverleaf_Rolls_4',
#  'Homemade_Cloverleaf_Rolls_5',
#  'Homemade_Cherry_Ice_Cream_Recipe_No_Ice_Cream_Maker_Required_0',
#  'Homemade_Cherry_Ice_Cream_Recipe_No_Ice_Cream_Maker_Required_1',
#  'Homemade_Cherry_Ice_Cream_Recipe_No_Ice_Cream_Maker_Required_2',
#  'Homemade_Cherry_Ice_Cream_Recipe_No_Ice_Cream_Maker_Required_3',
#  'Microwave_Strawberry_Jam____3_ingredients__0',
#  'Microwave_Strawberry_Jam____3_ingredients__1',
#  'Microwave_Strawberry_Jam____3_ingredients__2',
#  'Microwave_Strawberry_Jam____3_ingredients__3',
#  'Chicken_Stir_Fry_0',
#  'Chicken_Stir_Fry_1',
#  'Chicken_Stir_Fry_2',
#  'Chicken_Stir_Fry_3',
#  'Baked_Cajun_Chicken_Thighs_0',
#  'Baked_Cajun_Chicken_Thighs_1',
#  'Baked_Cajun_Chicken_Thighs_2',
#  'Baked_Cajun_Chicken_Thighs_3',
#  'Homemade_Rich_Cherry_Eggnog_0',
#  'Homemade_Rich_Cherry_Eggnog_1',
#  'Cinnamon_Coffee_Cake_0',
#  'Cinnamon_Coffee_Cake_1',
#  'Cinnamon_Coffee_Cake_2',
#  'Slow_Cooker_Mongolian_Beef_0',
#  'Slow_Cooker_Mongolian_Beef_1',
#  'Slow_Cooker_Mongolian_Beef_2',
#  'Slow_Cooker_Mongolian_Beef_3',
#  'Mixed_Berry_Jam_No_Pectin__Low_Sugar__0',
#  'Mixed_Berry_Jam_No_Pectin__Low_Sugar__1',
#  'Mixed_Berry_Jam_No_Pectin__Low_Sugar__2',
#  'Mixed_Berry_Jam_No_Pectin__Low_Sugar__3',
#  'Mixed_Berry_Jam_No_Pectin__Low_Sugar__4',
#  'Blackberry_Clafoutis_0',
#  'Blackberry_Clafoutis_1',
#  'Blackberry_Clafoutis_2',
#  'Orange_Marmalade_No_Pectin_0',
#  'Orange_Marmalade_No_Pectin_1',
#  'Orange_Marmalade_No_Pectin_2',
#  'Orange_Marmalade_No_Pectin_3',
#  'Tandoori_Prawn_Masala_0',
#  'Tandoori_Prawn_Masala_1',
#  'Tandoori_Prawn_Masala_2',
#  'Slow_Cooker_Indian_Chicken_Curry_0',
#  'Slow_Cooker_Indian_Chicken_Curry_1',
#  'Slow_Cooker_Indian_Chicken_Curry_2',
#  'Slow_Cooker_Indian_Chicken_Curry_3',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_0',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_1',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_2',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_3',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_4',
#  'Blackberry_Nectarine_Crumb_Cake_Recipe_5',
#  'Soft_Brioche_Buns_Homemade_0',
#  'Soft_Brioche_Buns_Homemade_1',
#  'Soft_Brioche_Buns_Homemade_2',
#  'The_BEST_Cherry_Filling_0',
#  'The_BEST_Cherry_Filling_1',
#  'The_BEST_Cherry_Filling_2',
#  'The_BEST_Cherry_Filling_3',
#  'No_Churn_Tiramisu_Ice_Cream_0',
#  'No_Churn_Tiramisu_Ice_Cream_1',
#  'No_Churn_Tiramisu_Ice_Cream_2',
#  'Honey_Balsamic_Chicken_0',
#  'Honey_Balsamic_Chicken_1',
#  'Honey_Balsamic_Chicken_2',
#  'Honey_Balsamic_Chicken_3',
#  'Honey_Balsamic_Chicken_4',
#  'Honey_Balsamic_Chicken_5',
#  'Honey_Balsamic_Chicken_6',
#  'Honey_Balsamic_Chicken_7',
#  'Mongolian_Meatballs_0',
#  'Mongolian_Meatballs_1',
#  'Mongolian_Meatballs_2',
#  'Mongolian_Meatballs_3',
#  'The_Best_Chocolate_Sugar_Cookie_Recipe_0',
#  'The_Best_Chocolate_Sugar_Cookie_Recipe_1',
#  'The_Best_Chocolate_Sugar_Cookie_Recipe_2',
#  'The_Best_Chocolate_Sugar_Cookie_Recipe_3',
#  'One_Bowl_Vanilla_Cake_Recipe_0',
#  'One_Bowl_Vanilla_Cake_Recipe_1',
#  'One_Bowl_Vanilla_Cake_Recipe_2',
#  'One_Bowl_Vanilla_Cake_Recipe_3',
#  'One_Bowl_Vanilla_Cake_Recipe_4',
#  'One_Bowl_Vanilla_Cake_Recipe_5',
#  'One_Bowl_Vanilla_Cake_Recipe_6',
#  'Homemade_Dulce_De_Leche___2_methods_0',
#  'Homemade_Dulce_De_Leche___2_methods_1',
#  'Homemade_Dulce_De_Leche___2_methods_2',
#  'Homemade_Dulce_De_Leche___2_methods_3',
#  'Strawberry_Vodka_Cocktail_0',
#  'Strawberry_Vodka_Cocktail_1',
#  'Strawberry_Vodka_Cocktail_2',
#  'The_BEST_White_Sandwich_Bread_Recipe_0',
#  'Easy_Strawberry_Tart_0',
#  'Easy_Strawberry_Tart_1',
#  'Easy_Strawberry_Tart_2',
#  'Easy_Strawberry_Tart_3',
#  'Easy_Strawberry_Tart_4',
#  'Meat_Patties___Meat_stuffed_Puff_Pastry_0',
#  'Meat_Patties___Meat_stuffed_Puff_Pastry_1',
#  'Meat_Patties___Meat_stuffed_Puff_Pastry_2',
#  'Meat_Patties___Meat_stuffed_Puff_Pastry_3',
#  'Meat_Patties___Meat_stuffed_Puff_Pastry_4',
#  'Quick_Chicken_Tikka_Masala_in_20_mins_0',
#  'Quick_Chicken_Tikka_Masala_in_20_mins_1',
#  'Quick_Chicken_Tikka_Masala_in_20_mins_2',
#  'Custard_Cookies__Eggless__0',
#  'Custard_Cookies__Eggless__1',
#  'Custard_Cookies__Eggless__2',
#  'Strawberry_Doughnuts___Sufganiyah_0',
#  'Strawberry_Doughnuts___Sufganiyah_1',
#  'Strawberry_Doughnuts___Sufganiyah_2',
#  'Strawberry_Doughnuts___Sufganiyah_3',
#  'Bakery_Style_White_Wedding_Cake_0',
#  'Bakery_Style_White_Wedding_Cake_1',
#  'Bakery_Style_White_Wedding_Cake_2',
#  'Bakery_Style_White_Wedding_Cake_3',
#  'Bakery_Style_White_Wedding_Cake_4',
#  'Bakery_Style_White_Wedding_Cake_5',
#  'The_Ultimate_Raspberry_Filling_0',
#  'The_Ultimate_Raspberry_Filling_1',
#  'The_Ultimate_Raspberry_Filling_2',
#  'The_Ultimate_Raspberry_Filling_3',
#  'The_Ultimate_Raspberry_Filling_4',
#  'Indian_Baked_Chicken_Curry_0',
#  'Indian_Baked_Chicken_Curry_1',
#  'Indian_Baked_Chicken_Curry_2',
#  'Indian_Baked_Chicken_Curry_3',
#  'Parisian_Flan__French_Custard_Tart_0',
#  'Parisian_Flan__French_Custard_Tart_1',
#  'Parisian_Flan__French_Custard_Tart_2',
#  'Parisian_Flan__French_Custard_Tart_3',
#  'Mini_Pumpkin_Cake_Donuts_Recipe_0',
#  'Mini_Pumpkin_Cake_Donuts_Recipe_1',
#  'Brioche_Sandwich_Bread_Recipe_0',
#  'Brioche_Sandwich_Bread_Recipe_1',
#  'Brioche_Sandwich_Bread_Recipe_2',
#  'Brioche_Sandwich_Bread_Recipe_3',
#  'Brioche_Sandwich_Bread_Recipe_4',
#  'Brioche_Sandwich_Bread_Recipe_5',
#  'Fudgy_Chocolate_Cookies_0',
#  'Fudgy_Chocolate_Cookies_1',
#  'Fudgy_Chocolate_Cookies_2',
#  'Fudgy_Chocolate_Cookies_3',
#  'Fudgy_Chocolate_Cookies_4',
#  'Halloween_Eyeball_Cookies_0',
#  'Halloween_Eyeball_Cookies_1',
#  'Halloween_Eyeball_Cookies_2',
#  'Halloween_Eyeball_Cookies_3',
#  'Halloween_Eyeball_Cookies_4',
#  'Best_Strawberry_Mousse_0',
#  'Best_Strawberry_Mousse_1',
#  'Best_Strawberry_Mousse_2',
#  'Best_Strawberry_Mousse_3',
#  'Best_Strawberry_Mousse_4',
#  'Best_Strawberry_Mousse_5',
#  'Homemade_Vanilla_Extract_0',
#  'Homemade_Vanilla_Extract_1',
#  'Homemade_Vanilla_Extract_2',
#  'Homemade_Vanilla_Extract_3',
#  'Homemade_Vanilla_Extract_4',
#  'Butterscotch_Cake_for_Two_0',
#  'Butterscotch_Cake_for_Two_1',
#  'Butterscotch_Cake_for_Two_2',
#  'Butterscotch_Cake_for_Two_3',
#  'Butterscotch_Cake_for_Two_4',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_0',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_1',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_2',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_3',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_4',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_5',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_6',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_7',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_8',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_9',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_10',
#  'The_Best_Vanilla_Sugar_Cookie_Recipe_11',
#  'Ginger_Shortbread_Bars_with_Molasses_0',
#  'Ginger_Shortbread_Bars_with_Molasses_1',
#  'Ginger_Shortbread_Bars_with_Molasses_2',
#  'Ginger_Shortbread_Bars_with_Molasses_3',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_0',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_1',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_2',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_3',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_4',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_5',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_6',
#  'Diabetic_Chocolate_Cake_with_Diabetic_Chocolate_Frosting_7',
#  'Homemade_Belgian_Chocolate_Ice_Cream__No_Churn__0',
#  'Homemade_Belgian_Chocolate_Ice_Cream__No_Churn__1',
#  'Homemade_Belgian_Chocolate_Ice_Cream__No_Churn__2',
#  'Homemade_Belgian_Chocolate_Ice_Cream__No_Churn__3',
#  'Homemade_Belgian_Chocolate_Ice_Cream__No_Churn__4',
#  'Homemade_Yogurt_Parfait_0',
#  'Homemade_Yogurt_Parfait_1',
#  'Homemade_Yogurt_Parfait_2',
#  'Homemade_Yogurt_Parfait_3',
#  'Homemade_Yogurt_Parfait_4',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_0',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_1',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_2',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_3',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_4',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_5',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_6',
#  'The_BEST_Beef_Burgundy_aka_Beef_Bourguignon_7',
#  'Beef_Curry___Slow_Cooked_0',
#  'Beef_Curry___Slow_Cooked_1',
#  'Beef_Curry___Slow_Cooked_2',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_0',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_1',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_2',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_3',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_4',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_5',
#  'How_to_make_Indian_Chapati_aka_Whole_Wheat_Tortilla_6',
#  'Homemade_Pepperoni_Pizza_from_Scratch_0',
#  'Homemade_Pepperoni_Pizza_from_Scratch_1',
#  'Homemade_Pepperoni_Pizza_from_Scratch_2',
#  'Homemade_Pepperoni_Pizza_from_Scratch_3',
#  'Honey_Garlic_Salmon_0',
#  'Honey_Garlic_Salmon_1',
#  'Honey_Garlic_Salmon_2',
#  'Honey_Garlic_Salmon_3',
#  'Lamb_Rogan_Josh_0',
#  'Lamb_Rogan_Josh_1',
#  'Lamb_Rogan_Josh_2',
#  'Lamb_Rogan_Josh_3',
#  'Lamb_Rogan_Josh_4',
#  'Mango_Cheesecake___Baked_0',
#  'Mango_Cheesecake___Baked_1',
#  'Mango_Cheesecake___Baked_2',
#  'Blueberry_Bars_0',
#  'Blueberry_Bars_1',
#  'Blueberry_Bars_2',
#  'Blueberry_Bars_3',
#  'Blueberry_Bars_4',
#  'Blueberry_Bars_5',
#  'Blueberry_Bars_6',
#  'Valentine_Chocolate_Fudge_Cake_For_Two_0',
#  'Valentine_Chocolate_Fudge_Cake_For_Two_1',
#  'Valentine_Chocolate_Fudge_Cake_For_Two_2',
#  'Valentine_Chocolate_Fudge_Cake_For_Two_3',
#  'Valentine_Chocolate_Fudge_Cake_For_Two_4',
#  'Homemade_Mulled_Wine_0',
#  'Homemade_Mulled_Wine_1',
#  'Homemade_Mulled_Wine_2',
#  'Hyderabad_Chicken_Biryani_0',
#  'Hyderabad_Chicken_Biryani_1',
#  'Hyderabad_Chicken_Biryani_2',
#  'Hyderabad_Chicken_Biryani_3',
#  'Moist_Vanilla_Cupcakes__one_bowl__0',
#  'Moist_Vanilla_Cupcakes__one_bowl__1',
#  'Moist_Vanilla_Cupcakes__one_bowl__2',
#  'Homemade_Hot_Cocoa_Eggnog_0',
#  'Homemade_Hot_Cocoa_Eggnog_1',
#  'Homemade_Naan___Indian_Flatbread_0',
#  'Homemade_Naan___Indian_Flatbread_1',
#  'Homemade_Naan___Indian_Flatbread_2',
#  'Homemade_Naan___Indian_Flatbread_3',
#  'Homemade_Naan___Indian_Flatbread_4',
#  'Homemade_Naan___Indian_Flatbread_5',
#  'Easy_Apple_Strudel_Recipe_with_Filo_Pastry_0',
#  'Easy_Apple_Strudel_Recipe_with_Filo_Pastry_1',
#  'Easy_Apple_Strudel_Recipe_with_Filo_Pastry_2',
#  'Easy_Apple_Strudel_Recipe_with_Filo_Pastry_3',
#  'Eggnog_Yule_Log_Cake___Buche_de_Noel_0',
#  'Eggnog_Yule_Log_Cake___Buche_de_Noel_1',
#  'Eggnog_Yule_Log_Cake___Buche_de_Noel_2',
#  'Eggnog_Yule_Log_Cake___Buche_de_Noel_3',
#  'Braised_Lamb_in_Red_Wine_0',
#  'Braised_Lamb_in_Red_Wine_1',
#  'Braised_Lamb_in_Red_Wine_2',
#  'Braised_Lamb_in_Red_Wine_3',
#  'Braised_Lamb_in_Red_Wine_4',
#  'Homemade_Piping_Gel___Two_Recipes___Gelatin_or_Vegetarian_0',
#  'Homemade_Piping_Gel___Two_Recipes___Gelatin_or_Vegetarian_1',
#  'Homemade_Piping_Gel___Two_Recipes___Gelatin_or_Vegetarian_2',
#  'Homemade_Piping_Gel___Two_Recipes___Gelatin_or_Vegetarian_3',
#  'Homemade_Piping_Gel___Two_Recipes___Gelatin_or_Vegetarian_4',
#  'Beef_Enchilada_Pasta_0',
#  'Beef_Enchilada_Pasta_1',
#  'Beef_Enchilada_Pasta_2',
#  'Beef_Enchilada_Pasta_3',
#  'Easy_White_Pizza_0',
#  'Easy_White_Pizza_1',
#  'Easy_White_Pizza_2',
#  'Easy_White_Pizza_3',
#  'Easy_White_Pizza_4',
#  'Easy_White_Pizza_5',
#  'Indian_Meatball_Curry_Recipe_0',
#  'Indian_Meatball_Curry_Recipe_1',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_0',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_1',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_2',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_3',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_4',
#  'Almond_Cream_Blackberry_Braided_Puff_Pastry_5',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_0',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_1',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_2',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_3',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_4',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_5',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_6',
#  'Strawberry_Mousse_Domes_with_Pastry_Cream_Insert_7',
#  '4_Ways_to_Make_Homemade_Buttermilk_0',
#  '4_Ways_to_Make_Homemade_Buttermilk_1',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_0',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_1',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_2',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_3',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_4',
#  'The_BEST_Fried_Rice_Recipe_Ready_in_15_Minutes_5',
#  'Easy_Soft_Flatbread_Recipes_0',
#  'Easy_Soft_Flatbread_Recipes_1',
#  'Easy_Soft_Flatbread_Recipes_2',
#  'Easy_Soft_Flatbread_Recipes_3',
#  'Easy_Soft_Flatbread_Recipes_4',
#  'Homemade_Mocha_Frappuccino_0',
#  'Homemade_Mocha_Frappuccino_1',
#  'Chicken_Pasta_Recipe_0',
#  'Chicken_Pasta_Recipe_1',
#  'Chicken_Pasta_Recipe_2',
#  'Chicken_Pasta_Recipe_3',
#  'Quick_Chicken_Curry___6_Ingredients_0',
#  'Quick_Chicken_Curry___6_Ingredients_1',
#  'Parmesan_Garlic_Rolls_0',
#  'Parmesan_Garlic_Rolls_1',
#  'Parmesan_Garlic_Rolls_2',
#  'Parmesan_Garlic_Rolls_3',
#  '3_Cheese_Pizza_0',
#  '3_Cheese_Pizza_1',
#  'Scrumptious_Brown_Sugar_Cupcakes_0',
#  'Scrumptious_Brown_Sugar_Cupcakes_1',
#  'Chocolate_Cake_Perfect_for_Carving_0',
#  'Chocolate_Cake_Perfect_for_Carving_1',
#  'Caramel_Banana_Cake_0',
#  'Caramel_Banana_Cake_1',
#  'Caramel_Banana_Cake_2',
#  'Ham_and_Cheese_Croissants_0',
#  'Ham_and_Cheese_Croissants_1',
#  'Lamb_with_Pasta_0',
#  'Lamb_with_Pasta_1',
#  'Old_Fashioned_Gingerbread_Cupcakes_with_Chocolate_Fudge_Frosting_0',
#  'Old_Fashioned_Gingerbread_Cupcakes_with_Chocolate_Fudge_Frosting_1',
#  'Old_Fashioned_Gingerbread_Cupcakes_with_Chocolate_Fudge_Frosting_2',
#  'Old_Fashioned_Gingerbread_Cupcakes_with_Chocolate_Fudge_Frosting_3',
#  'Creamy_Semolina_Pudding_with_Fruit_and_Nuts_0',
#  'Creamy_Semolina_Pudding_with_Fruit_and_Nuts_1',
#  'Creamy_Semolina_Pudding_with_Fruit_and_Nuts_2',
#  'Creamy_Semolina_Pudding_with_Fruit_and_Nuts_3',
#  'Creamy_Semolina_Pudding_with_Fruit_and_Nuts_4',
#  'Chocolate_Rugelach_Cookies_0',
#  'Chocolate_Rugelach_Cookies_1',
#  'Chocolate_Rugelach_Cookies_2',
#  'Chocolate_Rugelach_Cookies_3',
#  'Triple_Chocolate_Pumpkin_Tart_0',
#  'Triple_Chocolate_Pumpkin_Tart_1',
#  'Triple_Chocolate_Pumpkin_Tart_2',
#  'Triple_Chocolate_Pumpkin_Tart_3',
#  'Mini_Lamb_Pot_Pies_with_Biscuits_0',
#  'Mini_Lamb_Pot_Pies_with_Biscuits_1',
#  'Mini_Lamb_Pot_Pies_with_Biscuits_2',
#  'Mini_Lamb_Pot_Pies_with_Biscuits_3',
#  'Mini_Lamb_Pot_Pies_with_Biscuits_4',
#  'Blueberry_Cream_Cake_with_Crumb_Topping_0',
#  'Blueberry_Cream_Cake_with_Crumb_Topping_1',
#  'Blueberry_Cream_Cake_with_Crumb_Topping_2',
#  'Blueberry_Cream_Cake_with_Crumb_Topping_3',
#  'Blueberry_Cream_Cake_with_Crumb_Topping_4',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_0',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_1',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_2',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_3',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_4',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_5',
#  'Moroccan_Fish_in_Spicy_Tomato_Sauce_Chraime_6',
#  'Strawberry_Ice_Cream___No_Churn_0',
#  'Strawberry_Ice_Cream___No_Churn_1',
#  'Strawberry_Ice_Cream___No_Churn_2',
#  'Homemade_Cauliflower_Soup_0',
#  'Homemade_Cauliflower_Soup_1',
#  'Homemade_Cauliflower_Soup_2',
#  'Homemade_Cauliflower_Soup_3',
#  'Pistachio_Cherry_Fruitcake_0',
#  'Pistachio_Cherry_Fruitcake_1',
#  'Pistachio_Cherry_Fruitcake_2',
#  'Cinnamon_Chocolate_Babka_Recipe_0',
#  'Cinnamon_Chocolate_Babka_Recipe_1',
#  'Cilantro_Baked_Fish_0',
#  'Cilantro_Baked_Fish_1',
#  'Cilantro_Baked_Fish_2',
#  'Cilantro_Baked_Fish_3',
#  'Cilantro_Baked_Fish_4',
#  'Cilantro_Baked_Fish_5',
#  'Raspberry_White_Chocolate_Cake_0',
#  'Raspberry_White_Chocolate_Cake_1',
#  'Raspberry_White_Chocolate_Cake_2',
#  'Simple_Moist_Chocolate_Cake_0',
#  'Simple_Moist_Chocolate_Cake_1',
#  'Classic_Puff_Pastry_from_Scratch_0',
#  'Classic_Puff_Pastry_from_Scratch_1',
#  'Classic_Puff_Pastry_from_Scratch_2',
#  'Classic_Puff_Pastry_from_Scratch_3',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_0',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_1',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_2',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_3',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_4',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_5',
#  'Simple_Easy_Lemon_Butter_Baked_Chicken_6',
#  'Oreo_Ice_Cream__No_Churn__0',
#  'Oreo_Ice_Cream__No_Churn__1',
#  'Oreo_Ice_Cream__No_Churn__2',
#  'Oreo_Ice_Cream__No_Churn__3',
#  'Easy_Prawn_Curry_0',
#  'Easy_Prawn_Curry_1',
#  'Easy_Prawn_Curry_2',
#  'The_Ultimate_Pecan_Pie_Brownie_0',
#  'The_Ultimate_Pecan_Pie_Brownie_1',
#  'The_Ultimate_Pecan_Pie_Brownie_2',
#  'The_Ultimate_Pecan_Pie_Brownie_3',
#  'The_Ultimate_Pecan_Pie_Brownie_4',
#  'Blueberry_Banana_Smoothie_0',
#  'Blueberry_Banana_Smoothie_1',
#  'Blueberry_Banana_Smoothie_2',
#  'Slow_cooker_Lamb_Curry_0',
#  'Slow_cooker_Lamb_Curry_1',
#  'Slow_cooker_Lamb_Curry_2',
#  'Slow_cooker_Lamb_Curry_3',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_0',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_1',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_2',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_3',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_4',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_5',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_6',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_7',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_8',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_9',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_10',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_11',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_12',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_13',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_14',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_15',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_16',
#  'Caramelized_Onions_Roasted_Red_Peppers_Quiche_17',
#  'Danish_Cream_Cheese_Cylinders_0',
#  'Danish_Cream_Cheese_Cylinders_1',
#  'Strawberry_Cheesecake___Baked_0',
#  'Strawberry_Cheesecake___Baked_1',
#  'Strawberry_Cheesecake___Baked_2',
#  'Strawberry_Cheesecake___Baked_3',
#  'Thin_Crisp_Chocolate_Chip_Cookies_0',
#  'Thin_Crisp_Chocolate_Chip_Cookies_1',
#  'Thin_Crisp_Chocolate_Chip_Cookies_2',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_0',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_1',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_2',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_3',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_4',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_5',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_6',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_7',
#  'Easy_Pumpkin_Cupcakes_with_Cream_Cheese_Frosting_8',
#  'Gingerbread_Sugar_Cookies_0',
#  'Gingerbread_Sugar_Cookies_1',
#  'Gingerbread_Sugar_Cookies_2',
#  'Gingerbread_Sugar_Cookies_3',
#  'Gingerbread_Sugar_Cookies_4',
#  'Vanilla_Sculpting_Cake_Recipe_0',
#  'Vanilla_Sculpting_Cake_Recipe_1',
#  'Vanilla_Sculpting_Cake_Recipe_2',
#  'Everyday_No_Chill_Chocolate_Chip_Cookies_0',
#  'Everyday_No_Chill_Chocolate_Chip_Cookies_1',
#  'Everyday_No_Chill_Chocolate_Chip_Cookies_2',
#  'Everyday_No_Chill_Chocolate_Chip_Cookies_3',
#  'Everyday_No_Chill_Chocolate_Chip_Cookies_4',
#  'Cinnamon_Caramel_Apple_Tarts_0',
#  'Cinnamon_Caramel_Apple_Tarts_1',
#  'Cinnamon_Caramel_Apple_Tarts_2',
#  'Cinnamon_Caramel_Apple_Tarts_3',
#  'Cinnamon_Caramel_Apple_Tarts_4',
#  'Cinnamon_Caramel_Apple_Tarts_5',
#  'Crustless_Strawberry_Ricotta_Cheesecake_0',
#  'Homemade_Hot_Chocolate_0',
#  'Easy_Cinnamon_Rolls_from_Scratch_0',
#  'Easy_Cinnamon_Rolls_from_Scratch_1',
#  'Easy_Cinnamon_Rolls_from_Scratch_2',
#  'Easy_Cinnamon_Rolls_from_Scratch_3',
#  'Easy_Cinnamon_Rolls_from_Scratch_4',
#  'Easy_Cinnamon_Rolls_from_Scratch_5',
#  'Chocolate_Chiffon_Cake_0',
#  'Chocolate_Chiffon_Cake_1',
#  'Chocolate_Chiffon_Cake_2',
#  'Chocolate_Chiffon_Cake_3',
#  'Homemade_Fruit_and_Nut_Granola_0',
#  'Homemade_Fruit_and_Nut_Granola_1',
#  'Butternut_Squash_Fries_0',
#  'Butternut_Squash_Fries_1',
#  'Butternut_Squash_Fries_2',
#  'Homemade_Chicken_Burgers_0',
#  'Homemade_Chicken_Burgers_1',
#  'Homemade_Chicken_Burgers_2',
#  'Homemade_Chicken_Burgers_3',
#  'Homemade_Chicken_Burgers_4',
#  'Homemade_Chicken_Burgers_5',
#  'Homemade_Chicken_Burgers_6',
#  'Homemade_Chicken_Burgers_7',
#  'Olive_Pizza_with_Red_Onions_0',
#  'Olive_Pizza_with_Red_Onions_1',
#  'Olive_Pizza_with_Red_Onions_2',
#  'Olive_Pizza_with_Red_Onions_3',
#  'Olive_Pizza_with_Red_Onions_4',
#  'Homemade_Gumpaste_Recipe__Edible__0',
#  'Homemade_Gumpaste_Recipe__Edible__1',
#  'Rosemary_Focaccia_Bread_0',
#  'Rosemary_Focaccia_Bread_1',
#  'Rosemary_Focaccia_Bread_2',
#  'Rosemary_Focaccia_Bread_3',
#  'Rosemary_Focaccia_Bread_4',
#  'Rosemary_Focaccia_Bread_5',
#  'Blackberry_Ice_Cream_No_Churn_0',
#  'Blackberry_Ice_Cream_No_Churn_1',
#  'Blackberry_Ice_Cream_No_Churn_2',
#  'Blackberry_Ice_Cream_No_Churn_3',
#  'Hamantaschen___Dates_0',
#  'Hamantaschen___Dates_1',
#  'Hamantaschen___Dates_2',
#  'Hamantaschen___Dates_3',
#  'Devils_Food_Chocolate_Cake_with_Chocolate_Ganache_0',
#  'Devils_Food_Chocolate_Cake_with_Chocolate_Ganache_1',
#  'Devils_Food_Chocolate_Cake_with_Chocolate_Ganache_2',
#  'Devils_Food_Chocolate_Cake_with_Chocolate_Ganache_3',
#  'Healthy_Potato_Leek_Soup_0',
#  'Healthy_Potato_Leek_Soup_1',
#  'Pumpkin_Spice_Caramel_Apple_Dessert_0',
#  'Turkey_Sandwich_0',
#  'Turkey_Sandwich_1',
#  'Turkey_Sandwich_2',
#  'Sweet_Mango_Chutney_0',
#  'Sweet_Mango_Chutney_1',
#  'Sweet_Mango_Chutney_2',
#  'Sweet_Mango_Chutney_3',
#  'Eggless_Chocolate_Cake_0',
#  'Eggless_Chocolate_Cake_1',
#  'Eggless_Chocolate_Cake_2',
#  'Eggless_Chocolate_Cake_3',
#  'Eggless_Chocolate_Cake_4',
#  'Eggless_Chocolate_Cake_5',
#  'Eggless_Chocolate_Cake_6',
#  'Spinach_Potato_Patties_0',
#  'Spinach_Potato_Patties_1',
#  'Spinach_Potato_Patties_2',
#  'Spinach_Potato_Patties_3',
#  'Black_Bean_Coconut_Curry__Vegan__0',
#  'Black_Bean_Coconut_Curry__Vegan__1',
#  'Black_Bean_Coconut_Curry__Vegan__2',
#  'Coffee_Crumble_Cake_0',
#  'Coffee_Crumble_Cake_1',
#  'Coffee_Crumble_Cake_2',
#  'Coffee_Crumble_Cake_3',
#  'Coffee_Crumble_Cake_4',
#  'Coffee_Crumble_Cake_5',
#  'Coffee_Crumble_Cake_6',
#  'Strawberry_Cream_Cake_0',
#  'Strawberry_Cream_Cake_1',
#  'Strawberry_Cream_Cake_2',
#  'Strawberry_Cream_Cake_3',
#  'Strawberry_Cream_Cake_4',
#  'Italian_Meringue_Buttercream_with_Meringue_Powder_0',
#  'Italian_Meringue_Buttercream_with_Meringue_Powder_1',
#  'Italian_Meringue_Buttercream_with_Meringue_Powder_2',
#  'Italian_Meringue_Buttercream_with_Meringue_Powder_3',
#  'Italian_Meringue_Buttercream_with_Meringue_Powder_4',
#  'Candy_Christmas_Cookies_0',
#  'Candy_Christmas_Cookies_1',
#  'Candy_Christmas_Cookies_2',
#  'Candy_Christmas_Cookies_3',
#  'Candy_Christmas_Cookies_4',
#  'Strawberry_Chocolate_Smoothie_0',
#  'Strawberry_Chocolate_Smoothie_1',
#  'Strawberry_Chocolate_Smoothie_2',
#  'How_to_Stabilize_Whipped_Cream_5_Methods_0',
#  'How_to_Stabilize_Whipped_Cream_5_Methods_1',
#  'How_to_Stabilize_Whipped_Cream_5_Methods_2',
#  'Rice_Pilaf_with_Fruit_and_Nuts_0',
#  'Rice_Pilaf_with_Fruit_and_Nuts_1',
#  'Rice_Pilaf_with_Fruit_and_Nuts_2',
#  'Rice_Pilaf_with_Fruit_and_Nuts_3',
#  'Rice_Pilaf_with_Fruit_and_Nuts_4',
#  'Eggless_Vanilla_Cake_Recipe_2_0',
#  'Chocolate_Birthday_Cake_0',
#  'Chocolate_Birthday_Cake_1',
#  'Dark_Nutella_Buttercream_Frosting_0',
#  'Dark_Nutella_Buttercream_Frosting_1',
#  'Dark_Nutella_Buttercream_Frosting_2',
#  'Dark_Nutella_Buttercream_Frosting_3',
#  'Slow_Cooker_Yellow_Lentil_Soup_0',
#  'Slow_Cooker_Yellow_Lentil_Soup_1',
#  'Slow_Cooker_Yellow_Lentil_Soup_2',
#  'Slow_Cooker_Yellow_Lentil_Soup_3',
#  'Best_Funfetti_Cake_0',
#  'Best_Funfetti_Cake_1',
#  'Best_Funfetti_Cake_2',
#  'Butterscotch_Buttercream_Frosting___2_Methods_0',
#  'Butterscotch_Buttercream_Frosting___2_Methods_1',
#  'Butterscotch_Buttercream_Frosting___2_Methods_2',
#  'Raspberry_Peach_Crumble_0',
#  'Raspberry_Peach_Crumble_1',
#  'Raspberry_Peach_Crumble_2',
#  'Raspberry_Peach_Crumble_3',
#  'Middle_Eastern_Chicken_Kebabs_0',
#  'Middle_Eastern_Chicken_Kebabs_1',
#  'Middle_Eastern_Chicken_Kebabs_2',
#  'Middle_Eastern_Chicken_Kebabs_3',
#  'Middle_Eastern_Chicken_Kebabs_4',
#  'Middle_Eastern_Chicken_Kebabs_5',
#  'Middle_Eastern_Chicken_Kebabs_6',
#  'Turkey_Meatballs_in_Tomato_sauce_0',
#  'Turkey_Meatballs_in_Tomato_sauce_1',
#  'Turkey_Meatballs_in_Tomato_sauce_2',
#  'Turkey_Meatballs_in_Tomato_sauce_3',
#  'Turkey_Meatballs_in_Tomato_sauce_4',
#  'Caramel_Filing_for_Cakes_Tarts_and_Desserts_0',
#  'Caramel_Filing_for_Cakes_Tarts_and_Desserts_1',
#  'Caramel_Filing_for_Cakes_Tarts_and_Desserts_2',
#  'Caramel_Filing_for_Cakes_Tarts_and_Desserts_3',
#  'Bakery_Style_Chocolate_Rugelach_0',
#  'Sheet_Pan_Paprika_Chicken_0',
#  'Sheet_Pan_Paprika_Chicken_1',
#  'Sheet_Pan_Paprika_Chicken_2',
#  'Sheet_Pan_Paprika_Chicken_3',
#  'Sheet_Pan_Paprika_Chicken_4',
#  'Mini_Cheesecakes_Raspberry_0',
#  'Mini_Cheesecakes_Raspberry_1',
#  'Mini_Cheesecakes_Raspberry_2',
#  'Mini_Cheesecakes_Raspberry_3',
#  'Frozen_Hot_Chocolate_0',
#  'Frozen_Hot_Chocolate_1',
#  'Frozen_Hot_Chocolate_2',
#  'Homemade_Condensed_Milk__2_methods__0',
#  'Homemade_Condensed_Milk__2_methods__1',
#  'Homemade_Granola___Blueberry_Almond_Granola_0',
#  'Homemade_Granola___Blueberry_Almond_Granola_1',
#  'Homemade_Granola___Blueberry_Almond_Granola_2',
#  'Homemade_Granola___Blueberry_Almond_Granola_3',
#  'Leek_and_Asparagus_Quiche_0',
#  'Leek_and_Asparagus_Quiche_1',
#  'Leek_and_Asparagus_Quiche_2',
#  'Leek_and_Asparagus_Quiche_3',
#  'Crispy_Chicken_Recipe___Baked_0',
#  'Crispy_Chicken_Recipe___Baked_1',
#  'Crispy_Chicken_Recipe___Baked_2',
#  'Hot_Cross_Buns_0',
#  'Hot_Cross_Buns_1',
#  'Hot_Cross_Buns_2',
#  'Hot_Cross_Buns_3',
#  'Hot_Cross_Buns_4',
#  'Hot_Cross_Buns_5',
#  'Hot_Cross_Buns_6',
#  'Hot_Cross_Buns_7',
#  'Ginger_Chicken_Stir_Fry_Recipe_0',
#  'Ginger_Chicken_Stir_Fry_Recipe_1',
#  'Ginger_Chicken_Stir_Fry_Recipe_2',
#  'Ginger_Chicken_Stir_Fry_Recipe_3',
#  'Ginger_Chicken_Stir_Fry_Recipe_4',
#  'Ginger_Chicken_Stir_Fry_Recipe_5',
#  'Blueberry_Ice_cream_No_Churn_0',
#  'Blueberry_Ice_cream_No_Churn_1',
#  'Blueberry_Ice_cream_No_Churn_2',
#  'Blueberry_Ice_cream_No_Churn_3',
#  'Aloo_Gobi___Sautéed_Cauliflower_and_Potatoes_0',
#  'Aloo_Gobi___Sautéed_Cauliflower_and_Potatoes_1',
#  'Aloo_Gobi___Sautéed_Cauliflower_and_Potatoes_2',
#  'Aloo_Gobi___Sautéed_Cauliflower_and_Potatoes_3',
#  'Pecan_Pie_Recipe_0',
#  'Pecan_Pie_Recipe_1',
#  'Pecan_Pie_Recipe_2',
#  'Pecan_Pie_Recipe_3',
#  'Pecan_Pie_Recipe_4',
#  'Pumpkin_Spice_Latte_Cake_0',
#  'Pumpkin_Spice_Latte_Cake_1',
#  'Pumpkin_Spice_Latte_Cake_2',
#  'Pumpkin_Spice_Latte_Cake_3',
#  'Pumpkin_Spice_Latte_Cake_4',
#  'Indian_Butter_Chicken_in_20_mins_0',
#  'Indian_Butter_Chicken_in_20_mins_1',
#  'Chicken_Sandwich_0',
#  'Chicken_Sandwich_1',
#  'Chicken_Sandwich_2',
#  'Homemade_Whipped_Cream_4_Methods_0',
#  'Homemade_Whipped_Cream_4_Methods_1',
#  'Homemade_Whipped_Cream_4_Methods_2',
#  'Tomato_Mozzarella_Salad_0',
#  'Tomato_Mozzarella_Salad_1',
#  'Tomato_Mozzarella_Salad_2',
#  'Pumpkin_Cake_Tutorial_0',
#  'Pumpkin_Cake_Tutorial_1',
#  'Pumpkin_Cake_Tutorial_2',
#  'Pumpkin_Cake_Tutorial_3',
#  'Homemade_Classic_Eggnog_Recipe_0',
#  'Homemade_Classic_Eggnog_Recipe_1',
#  'Homemade_Classic_Eggnog_Recipe_2',
#  'Roasted_Red_Pepper_Garlic_Tapenade_0',
#  'Roasted_Red_Pepper_Garlic_Tapenade_1',
#  'Roasted_Red_Pepper_Garlic_Tapenade_2',
#  'Roasted_Red_Pepper_Garlic_Tapenade_3',
#  'Roasted_Red_Pepper_Garlic_Tapenade_4',
#  'Roasted_Red_Pepper_Garlic_Tapenade_5',
#  'Roasted_Red_Pepper_Garlic_Tapenade_6',
#  'Roasted_Asparagus_with_Parmesan_0',
#  'Roasted_Asparagus_with_Parmesan_1',
#  'Roasted_Asparagus_with_Parmesan_2',
#  'Roasted_Asparagus_with_Parmesan_3',
#  'Pumpkin_Creme_Brûlée_Recipe_0',
#  'Pumpkin_Creme_Brûlée_Recipe_1',
#  'Pumpkin_Creme_Brûlée_Recipe_2',
#  'Coconut_Mango_Lassi_0',
#  'Coconut_Mango_Lassi_1',
#  'Coconut_Mango_Lassi_2',
#  'Nectarine_Frangipani_Tart_0',
#  'Maple_Buttercream_Frosting_0',
#  'Maple_Buttercream_Frosting_1',
#  'Maple_Buttercream_Frosting_2',
#  'Maple_Buttercream_Frosting_3',
#  'Heart_Chocolate_Terrine_0',
#  'Heart_Chocolate_Terrine_1',
#  'Heart_Chocolate_Terrine_2',
#  'Heart_Chocolate_Terrine_3',
#  'Heart_Chocolate_Terrine_4',
#  'Heart_Chocolate_Terrine_5',
#  'Heart_Chocolate_Terrine_6',
#  'Apple_Honey_Tarte_Tatin_0',
#  'Apple_Honey_Tarte_Tatin_1',
#  'Apple_Honey_Tarte_Tatin_2',
#  'Chicken_Skewers___Grilled_0',
#  'Chicken_Skewers___Grilled_1',
#  'Chicken_Skewers___Grilled_2',
#  'Chicken_Skewers___Grilled_3',
#  'Strawberry_Panna_Cotta_0',
#  'Strawberry_Panna_Cotta_1',
#  'Strawberry_Panna_Cotta_2',
#  'Strawberry_Panna_Cotta_3',
#  'Strawberry_Panna_Cotta_4',
#  'Strawberry_Panna_Cotta_5',
#  'Leek_and_Potato_Patties___Leek_Potato_Cakes_0',
#  'Leek_and_Potato_Patties___Leek_Potato_Cakes_1',
#  'Leek_and_Potato_Patties___Leek_Potato_Cakes_2',
#  'Quick_Chicken_Stir_Fry_with_Peppers_0',
#  'Quick_Chicken_Stir_Fry_with_Peppers_1',
#  'Quick_Chicken_Stir_Fry_with_Peppers_2',
#  'Quick_Chicken_Stir_Fry_with_Peppers_3',
#  'Quick_Chicken_Stir_Fry_with_Peppers_4',
#  'Quick_Chicken_Stir_Fry_with_Peppers_5',
#  'Moist_Chocolate_Cherry_Cake_0',
#  'Moist_Chocolate_Cherry_Cake_1',
#  'Moist_Chocolate_Cherry_Cake_2',
#  'Moist_Chocolate_Cherry_Cake_3',
#  'Moist_Chocolate_Cherry_Cake_4',
#  'Homemade_Vanilla_Bean_Paste_0',
#  'Homemade_Vanilla_Bean_Paste_1',
#  'Homemade_Vanilla_Bean_Paste_2',
#  'Homemade_Vanilla_Bean_Paste_3',
#  'No_Knead_Sandwich_Bread_Recipe_0',
#  'No_Knead_Sandwich_Bread_Recipe_1',
#  'No_Knead_Sandwich_Bread_Recipe_2',
#  'No_Knead_Sandwich_Bread_Recipe_3',
#  'No_Knead_Sandwich_Bread_Recipe_4',
#  'No_Knead_Sandwich_Bread_Recipe_5',
#  'Chocolate_Marshmallow_Fondant_0',
#  'Chocolate_Marshmallow_Fondant_1',
#  'Baked_Za_atar_Chicken_Recipe_0',
#  'Baked_Za_atar_Chicken_Recipe_1',
#  'Baked_Za_atar_Chicken_Recipe_2',
#  'Baked_Za_atar_Chicken_Recipe_3',
#  'Baked_Chicken_Potato_Casserole_0',
#  'Baked_Chicken_Potato_Casserole_1',
#  'Baked_Chicken_Potato_Casserole_2',
#  'Baked_Chicken_Potato_Casserole_3',
#  'Baked_Chicken_Potato_Casserole_4',
#  'Apple_Pie_Hamantaschen_Cookies_0',
#  'Apple_Pie_Hamantaschen_Cookies_1',
#  'Apple_Pie_Hamantaschen_Cookies_2',
#  'Apple_Pie_Hamantaschen_Cookies_3',
#  'Apple_Pie_Hamantaschen_Cookies_4',
#  'Baileys_Chocolate_Martini_0',
#  'Baileys_Chocolate_Martini_1',
#  'Baileys_Chocolate_Martini_2',
#  'Cream_of_Broccoli_Soup_0',
#  'Cream_of_Broccoli_Soup_1',
#  'Cream_of_Broccoli_Soup_2',
#  'Cream_of_Broccoli_Soup_3',
#  'Cream_of_Broccoli_Soup_4',
#  'Sugar_Free_Maple_Eggnog_0',
#  'Sugar_Free_Maple_Eggnog_1',
#  'Banana_Date_Smoothie_0',
#  'Banana_Date_Smoothie_1',
#  'Pistachio_Matcha_Ice_Cream_0',
#  'Pistachio_Matcha_Ice_Cream_1',
#  'Pistachio_Matcha_Ice_Cream_2',
#  'Carrot_Cupcakes_0',
#  'Carrot_Cupcakes_1',
#  'Carrot_Cupcakes_2',
#  'Best_Vanilla_Cupcakes_0',
#  'Chocolate_Pecan_Squares_0',
#  'Chocolate_Pecan_Squares_1',
#  'Chocolate_Pecan_Squares_2',
#  'Chocolate_Pecan_Squares_3',
#  'Classic_Blueberry_Tart_0',
#  'Classic_Blueberry_Tart_1',
#  'Classic_Blueberry_Tart_2',
#  'Easy_Couscous_Salad_in_10_minutes_0',
#  'Easy_Couscous_Salad_in_10_minutes_1',
#  'Easy_Couscous_Salad_in_10_minutes_2',
#  'Sheet_Pan_Lemon_Chicken_with_Mushrooms__Roasted_Garlic_and_Caramelized_Onions_0',
#  'Sheet_Pan_Lemon_Chicken_with_Mushrooms__Roasted_Garlic_and_Caramelized_Onions_1',
#  'Sheet_Pan_Lemon_Chicken_with_Mushrooms__Roasted_Garlic_and_Caramelized_Onions_2',
#  'Sheet_Pan_Lemon_Chicken_with_Mushrooms__Roasted_Garlic_and_Caramelized_Onions_3',
#  'Slow_Cooked_Lamb_Masala_or_Mutton_Masala_Recipe_0',
#  'Slow_Cooked_Lamb_Masala_or_Mutton_Masala_Recipe_1',
#  'Healthy_Crispy_General_Tso_s_Chicken_0',
#  'Healthy_Crispy_General_Tso_s_Chicken_1',
#  'Healthy_Crispy_General_Tso_s_Chicken_2',
#  'One_Pot_Chicken_Biryani_0',
#  'One_Pot_Chicken_Biryani_1',
#  'One_Pot_Chicken_Biryani_2',
#  'Best_Homemade_Chocolate_Fondant_Recipe_0',
#  'The_BEST_Molasses_Cookie_0',
#  'The_BEST_Molasses_Cookie_1',
#  'The_BEST_Molasses_Cookie_2',
#  'The_BEST_Molasses_Cookie_3',
#  'Crock_Pot_Beef_Stew_0',
#  'Crock_Pot_Beef_Stew_1',
#  'Crock_Pot_Beef_Stew_2',
#  'Sufganiyot___Jam_Doughnuts_0',
#  'Sufganiyot___Jam_Doughnuts_1',
#  'Easy_pumpkin_soup_0',
#  'Easy_pumpkin_soup_1',
#  'Easy_pumpkin_soup_2',
#  'No_Bake_Energy_Bites_with_Granola_and_Dates_0',
#  'Best_Kahlua_Buttercream_Frosting_0',
#  'Best_Kahlua_Buttercream_Frosting_1',
#  'Best_Kahlua_Buttercream_Frosting_2',
#  'Best_Kahlua_Buttercream_Frosting_3',
#  'Chocolate_Chip_Pumpkin_Cake_Recipe_0',
#  'Chocolate_Chip_Pumpkin_Cake_Recipe_1',
#  'Chocolate_Chip_Pumpkin_Cake_Recipe_2',
#  'Chocolate_Chip_Pumpkin_Cake_Recipe_3',
#  'Chocolate_Chip_Pumpkin_Cake_Recipe_4',
#  'Chocolate_Cheesecake_Tarts_0',
#  'Chocolate_Cheesecake_Tarts_1',
#  'Chocolate_Cheesecake_Tarts_2',
#  'Chocolate_Cheesecake_Tarts_3',
#  'Chocolate_Cheesecake_Tarts_4',
#  'Caramel_cupcakes_with_Swiss_meringue_buttercream_and_caramel_sauce_0',
#  'Caramel_cupcakes_with_Swiss_meringue_buttercream_and_caramel_sauce_1',
#  'Turmeric_Cauliflower_Rice_Pilaf_0',
#  'Turmeric_Cauliflower_Rice_Pilaf_1',
#  ...]

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

dataset = tf.data.Dataset.from_tensor_slices((images_path, text_index))

# Use map to load the numpy files in parallel
dataset = dataset.map(lambda item1, item2: tf.numpy_function(
          map_func, [item1, item2], [tf.float32, tf.int32]),
          num_parallel_calls=tf.data.AUTOTUNE)

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
class BahdanauAttention(tf.keras.Model):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)

    def call(self, features, hidden):
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        attention_hidden_layer = (tf.nn.tanh(self.W1(features) +
                                             self.W2(hidden_with_time_axis)))

        score = self.V(attention_hidden_layer)
        attention_weights = tf.nn.softmax(score, axis=1)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        return context_vector, attention_weights

class CNN_Encoder(tf.keras.Model):
    def __init__(self, embedding_dim):
        super(CNN_Encoder, self).__init__()
        # shape after fc == (batch_size, 64, embedding_dim)
        self.fc = tf.keras.layers.Dense(embedding_dim)

    def call(self, x):
        x = self.fc(x)
        x = tf.nn.relu(x)
        return x

class RNN_Decoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNN_Decoder, self).__init__()
        self.units = units

        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

    def call(self, x, features, hidden):
        # defining attention as a separate model
        context_vector, attention_weights = self.attention(features, hidden)

        # x shape after passing through embedding == (batch_size, 1, embedding_dim)
        x = self.embedding(x)

        # x shape after concatenation == (batch_size, 1, embedding_dim + hidden_size)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)

        # passing the concatenated vector to the GRU
        output, state = self.gru(x)

        # shape == (batch_size, max_length, hidden_size)
        x = self.fc1(output)

        # x shape == (batch_size * max_length, hidden_size)
        x = tf.reshape(x, (-1, x.shape[2]))

        # output shape == (batch_size * max_length, vocab)
        x = self.fc2(x)

        return x, state, attention_weights

    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNN_Encoder(embedding_dim)
decoder = RNN_Decoder(embedding_dim, units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')


def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
tf.saved_model.save(encoder, './model/encoder')

# %%
tf.saved_model.save(decoder, './model/decoder')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-6cda2f24372a> in <module>
# ----> 1 tf.saved_model.save(decoder, './model/decoder')
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in save(obj, export_dir, signatures, options)
#    1031
#    1032   _, exported_graph, object_saver, asset_info = _build_meta_graph(
# -> 1033       obj, signatures, options, meta_graph_def)
#    1034   saved_model.saved_model_schema_version = constants.SAVED_MODEL_SCHEMA_VERSION
#    1035
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph(obj, signatures, options, meta_graph_def)
#    1196
#    1197   with save_context.save_context(options):
# -> 1198     return _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in _build_meta_graph_impl(obj, signatures, options, meta_graph_def)
#    1131   if signatures is None:
#    1132     signatures = signature_serialization.find_function_to_export(
# -> 1133         checkpoint_graph_view)
#    1134
#    1135   signatures, wrapped_functions = (
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/signature_serialization.py in find_function_to_export(saveable_view)
#      73   # If the user did not specify signatures, check the root object for a function
#      74   # that can be made into a signature.
# ---> 75   functions = saveable_view.list_functions(saveable_view.root)
#      76   signature = functions.get(DEFAULT_SIGNATURE_ATTR, None)
#      77   if signature is not None:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/saved_model/save.py in list_functions(self, obj, extra_functions)
#     149     if obj_functions is None:
#     150       obj_functions = obj._list_functions_for_serialization(  # pylint: disable=protected-access
# --> 151           self._serialization_cache)
#     152       self._functions[obj] = obj_functions
#     153     if extra_functions:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _list_functions_for_serialization(self, serialization_cache)
#    2611     self.predict_function = None
#    2612     functions = super(
# -> 2613         Model, self)._list_functions_for_serialization(serialization_cache)
#    2614     self.train_function = train_function
#    2615     self.test_function = test_function
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in _list_functions_for_serialization(self, serialization_cache)
#    3085   def _list_functions_for_serialization(self, serialization_cache):
#    3086     return (self._trackable_saved_model_saver
# -> 3087             .list_functions_for_serialization(serialization_cache))
#    3088
#    3089   def __getstate__(self):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/base_serialization.py in list_functions_for_serialization(self, serialization_cache)
#      92       return {}
#      93
# ---> 94     fns = self.functions_to_serialize(serialization_cache)
#      95
#      96     # The parent AutoTrackable class saves all user-defined tf.functions, and
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/layer_serialization.py in functions_to_serialize(self, serialization_cache)
#      77   def functions_to_serialize(self, serialization_cache):
#      78     return (self._get_serialized_attributes(
# ---> 79         serialization_cache).functions_to_serialize)
#      80
#      81   def _get_serialized_attributes(self, serialization_cache):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/layer_serialization.py in _get_serialized_attributes(self, serialization_cache)
#      93
#      94     object_dict, function_dict = self._get_serialized_attributes_internal(
# ---> 95         serialization_cache)
#      96
#      97     serialized_attr.set_and_validate_objects(object_dict)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/model_serialization.py in _get_serialized_attributes_internal(self, serialization_cache)
#      49     # cache (i.e. this is the root level object).
#      50     if len(serialization_cache[constants.KERAS_CACHE_KEY]) == 1:
# ---> 51       default_signature = save_impl.default_save_signature(self.obj)
#      52
#      53     # Other than the default signature function, all other attributes match with
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/save_impl.py in default_save_signature(layer)
#     203   original_losses = _reset_layer_losses(layer)
#     204   fn = saving_utils.trace_model_call(layer)
# --> 205   fn.get_concrete_function()
#     206   _restore_layer_losses(original_losses)
#     207   return fn
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in get_concrete_function(self, *args, **kwargs)
#    1297       ValueError: if this object has not yet been called on concrete values.
#    1298     """
# -> 1299     concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1300     concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1301     return concrete
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1203       if self._stateful_fn is None:
#    1204         initializers = []
# -> 1205         self._initialize(args, kwargs, add_initializers_to=initializers)
#    1206         self._initialize_uninitialized_variables(initializers)
#    1207
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     724     self._concrete_stateful_fn = (
#     725         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 726             *args, **kwds))
#     727
#     728     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2967       args, kwargs = None, None
#    2968     with self._lock:
# -> 2969       graph_function, _ = self._maybe_define_function(args, kwargs)
#    2970     return graph_function
#    2971
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
# -> 3361           graph_function = self._create_graph_function(args, kwargs)
#    3362           self._function_cache.primary[cache_key] = graph_function
#    3363
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/saving/saving_utils.py in _wrapped_model(*args)
#     133     with base_layer_utils.call_context().enter(
#     134         model, inputs=inputs, build_graph=False, training=False, saving=True):
# --> 135       outputs = model(inputs, training=False)
#     136
#     137     # Outputs always has to be a flat dict.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/autograph/impl/api.py in wrapper(*args, **kwargs)
#     618   def wrapper(*args, **kwargs):
#     619     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 620       return func(*args, **kwargs)
#     621
#     622   if inspect.isfunction(func) or inspect.ismethod(func):
#
# TypeError: call() missing 2 required positional arguments: 'features' and 'hidden'

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * target.shape[0], 1)

    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)

            # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)
    
    print('finish Forward pass')
    total_loss = (loss / int(target.shape[1]))

    trainable_variables = encoder.trainable_variables + decoder.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))
    print('finish batch')
    return loss, total_loss

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
import time

EPOCHS = 50
num_steps = 2880/BATCH_SIZE
for epoch in range(EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        print(f'batch: {batch}')
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 10 == 0:
            average_batch_loss = batch_loss.numpy()/int(target.shape[1])
            print(f'Epoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')

    if epoch % 5 == 0:
        ckpt_manager.save()
    print(f'------> Epoch {epoch+1} Loss {total_loss/num_steps:.6f}')
    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# batch: 0
# Epoch 1 Batch 0 Loss 1.0016
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 1 Batch 10 Loss 0.9842
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 1 Batch 20 Loss 1.0472
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 1 Batch 30 Loss 0.8520
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 1 Batch 40 Loss 0.9534
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 1 Loss 1.005439
# Time taken for 1 epoch 22.32 sec
#
# batch: 0
# Epoch 2 Batch 0 Loss 0.9882
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 2 Batch 10 Loss 0.9460
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 2 Batch 20 Loss 1.0146
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 2 Batch 30 Loss 0.9861
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 2 Batch 40 Loss 0.9349
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 2 Loss 1.009778
# Time taken for 1 epoch 22.98 sec
#
# batch: 0
# Epoch 3 Batch 0 Loss 0.9312
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 3 Batch 10 Loss 0.8882
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 3 Batch 20 Loss 0.9555
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 3 Batch 30 Loss 1.0483
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 3 Batch 40 Loss 0.9919
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 3 Loss 1.001739
# Time taken for 1 epoch 22.88 sec
#
# batch: 0
# Epoch 4 Batch 0 Loss 1.0221
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 4 Batch 10 Loss 0.8437
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 4 Batch 20 Loss 1.0108
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 4 Batch 30 Loss 1.0723
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 4 Batch 40 Loss 0.9368
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 4 Loss 0.994966
# Time taken for 1 epoch 22.84 sec
#
# batch: 0
# Epoch 5 Batch 0 Loss 0.8754
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 5 Batch 10 Loss 1.0071
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 5 Batch 20 Loss 0.9437
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 5 Batch 30 Loss 0.9845
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 5 Batch 40 Loss 0.9026
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 5 Loss 0.997438
# Time taken for 1 epoch 22.98 sec
#
# batch: 0
# Epoch 6 Batch 0 Loss 1.0191
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 6 Batch 10 Loss 0.9908
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 6 Batch 20 Loss 0.9273
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 6 Batch 30 Loss 0.8831
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 6 Batch 40 Loss 0.9738
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 6 Loss 1.007824
# Time taken for 1 epoch 23.03 sec
#
# batch: 0
# Epoch 7 Batch 0 Loss 0.9599
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 7 Batch 10 Loss 0.9963
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 7 Batch 20 Loss 1.0119
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 7 Batch 30 Loss 1.0155
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 7 Batch 40 Loss 0.9654
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 7 Loss 1.000384
# Time taken for 1 epoch 22.31 sec
#
# batch: 0
# Epoch 8 Batch 0 Loss 0.9085
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 8 Batch 10 Loss 0.9999
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 8 Batch 20 Loss 0.9534
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 8 Batch 30 Loss 0.8697
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 8 Batch 40 Loss 0.9292
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 8 Loss 1.001001
# Time taken for 1 epoch 23.07 sec
#
# batch: 0
# Epoch 9 Batch 0 Loss 0.9394
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 9 Batch 10 Loss 0.9567
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 9 Batch 20 Loss 1.0344
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 9 Batch 30 Loss 0.9862
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 9 Batch 40 Loss 0.9728
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 9 Loss 1.012868
# Time taken for 1 epoch 23.35 sec
#
# batch: 0
# Epoch 10 Batch 0 Loss 0.9391
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 10 Batch 10 Loss 0.9379
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 10 Batch 20 Loss 0.9299
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 10 Batch 30 Loss 0.9444
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 10 Batch 40 Loss 1.0403
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 10 Loss 1.001432
# Time taken for 1 epoch 22.40 sec
#
# batch: 0
# Epoch 11 Batch 0 Loss 1.0006
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 11 Batch 10 Loss 1.0014
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 11 Batch 20 Loss 0.9325
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 11 Batch 30 Loss 0.9033
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 11 Batch 40 Loss 0.9851
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 11 Loss 0.994959
# Time taken for 1 epoch 22.70 sec
#
# batch: 0
# Epoch 12 Batch 0 Loss 0.9444
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 12 Batch 10 Loss 0.8555
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 12 Batch 20 Loss 0.9883
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 12 Batch 30 Loss 0.9669
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 12 Batch 40 Loss 1.0023
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 12 Loss 0.983344
# Time taken for 1 epoch 22.70 sec
#
# batch: 0
# Epoch 13 Batch 0 Loss 0.9487
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 13 Batch 10 Loss 0.9021
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 13 Batch 20 Loss 0.8684
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 13 Batch 30 Loss 1.0009
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 13 Batch 40 Loss 0.8850
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 13 Loss 0.998773
# Time taken for 1 epoch 22.83 sec
#
# batch: 0
# Epoch 14 Batch 0 Loss 0.9496
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 14 Batch 10 Loss 0.9709
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 14 Batch 20 Loss 0.9440
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 14 Batch 30 Loss 1.0652
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 14 Batch 40 Loss 0.9354
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 14 Loss 0.987616
# Time taken for 1 epoch 22.42 sec
#
# batch: 0
# Epoch 15 Batch 0 Loss 0.9104
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 15 Batch 10 Loss 0.9271
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 15 Batch 20 Loss 1.0041
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 15 Batch 30 Loss 0.9325
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 15 Batch 40 Loss 1.0678
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 15 Loss 0.998628
# Time taken for 1 epoch 22.81 sec
#
# batch: 0
# Epoch 16 Batch 0 Loss 0.8676
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 16 Batch 10 Loss 0.9833
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 16 Batch 20 Loss 0.8597
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 16 Batch 30 Loss 0.9260
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 16 Batch 40 Loss 0.9577
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 16 Loss 0.987301
# Time taken for 1 epoch 22.30 sec
#
# batch: 0
# Epoch 17 Batch 0 Loss 0.9119
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 17 Batch 10 Loss 1.0379
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 17 Batch 20 Loss 1.0363
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 17 Batch 30 Loss 0.9938
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 17 Batch 40 Loss 1.0833
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 17 Loss 0.983114
# Time taken for 1 epoch 22.71 sec
#
# batch: 0
# Epoch 18 Batch 0 Loss 1.0336
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 18 Batch 10 Loss 0.9226
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 18 Batch 20 Loss 1.0122
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 18 Batch 30 Loss 0.8961
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 18 Batch 40 Loss 1.1147
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 18 Loss 0.981652
# Time taken for 1 epoch 22.98 sec
#
# batch: 0
# Epoch 19 Batch 0 Loss 0.9537
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 19 Batch 10 Loss 0.9533
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 19 Batch 20 Loss 1.0002
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 19 Batch 30 Loss 1.0741
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 19 Batch 40 Loss 0.8833
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 19 Loss 0.995016
# Time taken for 1 epoch 23.05 sec
#
# batch: 0
# Epoch 20 Batch 0 Loss 1.0297
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 20 Batch 10 Loss 1.0249
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 20 Batch 20 Loss 0.9111
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 20 Batch 30 Loss 0.9600
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 20 Batch 40 Loss 0.9080
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 20 Loss 0.992258
# Time taken for 1 epoch 22.43 sec
#
# batch: 0
# Epoch 21 Batch 0 Loss 0.9050
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 21 Batch 10 Loss 0.9683
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 21 Batch 20 Loss 1.0012
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 21 Batch 30 Loss 0.9895
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 21 Batch 40 Loss 0.8881
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 21 Loss 0.987610
# Time taken for 1 epoch 22.52 sec
#
# batch: 0
# Epoch 22 Batch 0 Loss 0.9443
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 22 Batch 10 Loss 0.9177
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 22 Batch 20 Loss 1.0430
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 22 Batch 30 Loss 1.0092
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 22 Batch 40 Loss 1.0266
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 22 Loss 0.986834
# Time taken for 1 epoch 22.54 sec
#
# batch: 0
# Epoch 23 Batch 0 Loss 0.9442
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 23 Batch 10 Loss 0.9759
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 23 Batch 20 Loss 0.9659
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 23 Batch 30 Loss 0.9822
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 23 Batch 40 Loss 1.0252
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 23 Loss 0.983864
# Time taken for 1 epoch 22.28 sec
#
# batch: 0
# Epoch 24 Batch 0 Loss 0.9295
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 24 Batch 10 Loss 1.0731
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 24 Batch 20 Loss 1.0187
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 24 Batch 30 Loss 0.9834
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 24 Batch 40 Loss 1.0181
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 24 Loss 0.984723
# Time taken for 1 epoch 22.53 sec
#
# batch: 0
# Epoch 25 Batch 0 Loss 0.9374
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 25 Batch 10 Loss 1.0285
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 25 Batch 20 Loss 0.9955
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 25 Batch 30 Loss 1.0509
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 25 Batch 40 Loss 0.9694
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 25 Loss 0.973944
# Time taken for 1 epoch 22.85 sec
#
# batch: 0
# Epoch 26 Batch 0 Loss 0.9430
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 26 Batch 10 Loss 1.0097
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 26 Batch 20 Loss 1.0183
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 26 Batch 30 Loss 0.9248
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 26 Batch 40 Loss 0.9105
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 26 Loss 0.978001
# Time taken for 1 epoch 22.35 sec
#
# batch: 0
# Epoch 27 Batch 0 Loss 1.0077
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 27 Batch 10 Loss 1.0071
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 27 Batch 20 Loss 1.0032
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 27 Batch 30 Loss 1.0133
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 27 Batch 40 Loss 0.9898
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 27 Loss 0.983330
# Time taken for 1 epoch 22.92 sec
#
# batch: 0
# Epoch 28 Batch 0 Loss 0.9484
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 28 Batch 10 Loss 0.8512
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 28 Batch 20 Loss 0.9126
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 28 Batch 30 Loss 0.9739
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 28 Batch 40 Loss 0.8707
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 28 Loss 0.973347
# Time taken for 1 epoch 22.74 sec
#
# batch: 0
# Epoch 29 Batch 0 Loss 0.9468
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 29 Batch 10 Loss 0.8847
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 29 Batch 20 Loss 0.9724
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 29 Batch 30 Loss 0.9610
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 29 Batch 40 Loss 0.9385
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 29 Loss 0.979898
# Time taken for 1 epoch 22.19 sec
#
# batch: 0
# Epoch 30 Batch 0 Loss 1.0192
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 30 Batch 10 Loss 0.9408
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 30 Batch 20 Loss 1.0120
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 30 Batch 30 Loss 1.0100
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 30 Batch 40 Loss 1.0429
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 30 Loss 0.990360
# Time taken for 1 epoch 22.74 sec
#
# batch: 0
# Epoch 31 Batch 0 Loss 0.9792
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 31 Batch 10 Loss 0.9334
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 31 Batch 20 Loss 0.9127
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 31 Batch 30 Loss 0.9369
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 31 Batch 40 Loss 1.0272
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 31 Loss 0.989251
# Time taken for 1 epoch 23.04 sec
#
# batch: 0
# Epoch 32 Batch 0 Loss 1.0160
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 32 Batch 10 Loss 0.8509
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 32 Batch 20 Loss 1.0392
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 32 Batch 30 Loss 0.9268
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 32 Batch 40 Loss 1.0685
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 32 Loss 0.990622
# Time taken for 1 epoch 22.35 sec
#
# batch: 0
# Epoch 33 Batch 0 Loss 0.8704
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 33 Batch 10 Loss 0.9998
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 33 Batch 20 Loss 1.0417
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 33 Batch 30 Loss 1.1143
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 33 Batch 40 Loss 0.9845
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 33 Loss 1.011903
# Time taken for 1 epoch 22.47 sec
#
# batch: 0
# Epoch 34 Batch 0 Loss 1.0456
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 34 Batch 10 Loss 0.9367
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 34 Batch 20 Loss 1.0276
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 34 Batch 30 Loss 1.0062
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 34 Batch 40 Loss 0.9537
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 34 Loss 0.993589
# Time taken for 1 epoch 22.48 sec
#
# batch: 0
# Epoch 35 Batch 0 Loss 0.9033
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 35 Batch 10 Loss 0.9191
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 35 Batch 20 Loss 0.9324
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 35 Batch 30 Loss 0.9290
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 35 Batch 40 Loss 0.9795
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 35 Loss 0.980377
# Time taken for 1 epoch 21.80 sec
#
# batch: 0
# Epoch 36 Batch 0 Loss 1.0242
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 36 Batch 10 Loss 0.9108
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 36 Batch 20 Loss 0.9086
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 36 Batch 30 Loss 0.9040
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 36 Batch 40 Loss 1.0118
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 36 Loss 0.961744
# Time taken for 1 epoch 22.29 sec
#
# batch: 0
# Epoch 37 Batch 0 Loss 0.9679
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 37 Batch 10 Loss 0.8602
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 37 Batch 20 Loss 1.0526
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 37 Batch 30 Loss 1.0058
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 37 Batch 40 Loss 1.0217
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 37 Loss 0.962998
# Time taken for 1 epoch 22.27 sec
#
# batch: 0
# Epoch 38 Batch 0 Loss 1.0022
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 38 Batch 10 Loss 0.9251
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 38 Batch 20 Loss 1.0543
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 38 Batch 30 Loss 0.8609
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 38 Batch 40 Loss 1.0357
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 38 Loss 0.962025
# Time taken for 1 epoch 21.89 sec
#
# batch: 0
# Epoch 39 Batch 0 Loss 0.8547
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 39 Batch 10 Loss 1.0266
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 39 Batch 20 Loss 0.9120
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 39 Batch 30 Loss 1.0337
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 39 Batch 40 Loss 0.9748
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 39 Loss 0.966484
# Time taken for 1 epoch 22.27 sec
#
# batch: 0
# Epoch 40 Batch 0 Loss 0.9193
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 40 Batch 10 Loss 0.9006
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 40 Batch 20 Loss 1.0129
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 40 Batch 30 Loss 0.9600
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 40 Batch 40 Loss 0.9438
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 40 Loss 0.983464
# Time taken for 1 epoch 22.61 sec
#
# batch: 0
# Epoch 41 Batch 0 Loss 0.8780
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 41 Batch 10 Loss 0.9695
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 41 Batch 20 Loss 0.9634
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 41 Batch 30 Loss 0.9731
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 41 Batch 40 Loss 1.0014
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 41 Loss 0.976776
# Time taken for 1 epoch 22.25 sec
#
# batch: 0
# Epoch 42 Batch 0 Loss 0.9121
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 42 Batch 10 Loss 0.8775
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 42 Batch 20 Loss 0.8586
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 42 Batch 30 Loss 0.9704
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 42 Batch 40 Loss 0.8628
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 42 Loss 0.973219
# Time taken for 1 epoch 22.19 sec
#
# batch: 0
# Epoch 43 Batch 0 Loss 0.9097
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 43 Batch 10 Loss 0.9190
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 43 Batch 20 Loss 1.0457
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 43 Batch 30 Loss 0.8912
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 43 Batch 40 Loss 0.9885
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 43 Loss 0.971886
# Time taken for 1 epoch 22.14 sec
#
# batch: 0
# Epoch 44 Batch 0 Loss 0.9543
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 44 Batch 10 Loss 0.9630
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 44 Batch 20 Loss 0.9415
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 44 Batch 30 Loss 0.8885
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 44 Batch 40 Loss 0.8718
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 44 Loss 0.958188
# Time taken for 1 epoch 21.91 sec
#
# batch: 0
# Epoch 45 Batch 0 Loss 1.0280
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 45 Batch 10 Loss 0.9989
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 45 Batch 20 Loss 0.9734
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 45 Batch 30 Loss 0.9452
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 45 Batch 40 Loss 0.9422
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 45 Loss 0.950626
# Time taken for 1 epoch 22.69 sec
#
# batch: 0
# Epoch 46 Batch 0 Loss 0.9691
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 46 Batch 10 Loss 0.8500
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 46 Batch 20 Loss 0.9312
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 46 Batch 30 Loss 0.9013
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 46 Batch 40 Loss 0.9990
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 46 Loss 0.952671
# Time taken for 1 epoch 22.52 sec
#
# batch: 0
# Epoch 47 Batch 0 Loss 0.9856
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 47 Batch 10 Loss 0.9326
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 47 Batch 20 Loss 0.9407
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 47 Batch 30 Loss 0.9184
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 47 Batch 40 Loss 0.9097
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 47 Loss 0.953701
# Time taken for 1 epoch 22.11 sec
#
# batch: 0
# Epoch 48 Batch 0 Loss 0.9048
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 48 Batch 10 Loss 0.9045
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 48 Batch 20 Loss 0.9485
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 48 Batch 30 Loss 1.0651
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 48 Batch 40 Loss 0.9435
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 48 Loss 0.963558
# Time taken for 1 epoch 22.44 sec
#
# batch: 0
# Epoch 49 Batch 0 Loss 0.9697
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 49 Batch 10 Loss 0.9525
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 49 Batch 20 Loss 0.9449
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 49 Batch 30 Loss 1.0509
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 49 Batch 40 Loss 0.9674
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 49 Loss 0.966224
# Time taken for 1 epoch 22.39 sec
#
# batch: 0
# Epoch 50 Batch 0 Loss 0.9622
# batch: 1
# batch: 2
# batch: 3
# batch: 4
# batch: 5
# batch: 6
# batch: 7
# batch: 8
# batch: 9
# batch: 10
# Epoch 50 Batch 10 Loss 0.9244
# batch: 11
# batch: 12
# batch: 13
# batch: 14
# batch: 15
# batch: 16
# batch: 17
# batch: 18
# batch: 19
# batch: 20
# Epoch 50 Batch 20 Loss 1.0048
# batch: 21
# batch: 22
# batch: 23
# batch: 24
# batch: 25
# batch: 26
# batch: 27
# batch: 28
# batch: 29
# batch: 30
# Epoch 50 Batch 30 Loss 0.8875
# batch: 31
# batch: 32
# batch: 33
# batch: 34
# batch: 35
# batch: 36
# batch: 37
# batch: 38
# batch: 39
# batch: 40
# Epoch 50 Batch 40 Loss 0.9279
# batch: 41
# batch: 42
# batch: 43
# batch: 44
# batch: 45
# ------> Epoch 50 Loss 0.966646
# Time taken for 1 epoch 21.94 sec

# %%
def evaluate(image):
    attention_plot = np.zeros((max_length, 4))

    hidden = decoder.reset_state(batch_size=1)

    temp_input = tf.expand_dims(load_image(image)[0], 0)
    img_tensor_val = image_features_extract_model(temp_input)
    img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0],
                                                 -1,
                                                 img_tensor_val.shape[3]))

    features = encoder(img_tensor_val)

    dec_input = tf.expand_dims([tokenizer.word_index['<start>']], 0)
    result = []

    for i in range(max_length):
        predictions, hidden, attention_weights = decoder(dec_input,
                                                         features,
                                                         hidden)

        attention_plot[i] = tf.reshape(attention_weights, (-1, )).numpy()

        predicted_id = tf.random.categorical(predictions, 1)[0][0].numpy()
        result.append(tokenizer.index_word[predicted_id])

        if tokenizer.index_word[predicted_id] == '<end>':
            return result, attention_plot

        dec_input = tf.expand_dims([predicted_id], 0)

    attention_plot = attention_plot[:len(result), :]
    return result, attention_plot

def plot_attention(image, result, attention_plot):
    temp_image = np.array(Image.open(image))

    fig = plt.figure(figsize=(10, 10))

    len_result = len(result)
    for i in range(len_result):
        temp_att = np.resize(attention_plot[i], (8, 8))
        grid_size = max(np.ceil(len_result/2), 2)
        ax = fig.add_subplot(grid_size, grid_size, i+1)
        ax.set_title(result[i])
        img = ax.imshow(temp_image)
        ax.imshow(temp_att, cmap='gray', alpha=0.6, extent=img.get_extent())

    plt.show()

# %%
# captions on the validation set
from PIL import Image
import matplotlib.pyplot as plt

max_length = 500
rid = np.random.randint(0, len(images))
image = images[rid]
real_caption = ' '.join([tokenizer.index_word[i]
                        for i in text_index[rid] if i not in [0]])
result, attention_plot = evaluate(image)

print('Real Caption:', real_caption)
print('\nPrediction Caption:', ' '.join(result))
# Out:
# Real Caption: if necessary so the layers <unk> <unk> <sep> spread more chocolate <unk> around the cake and spread with a spatula <sep> use a <unk> <unk> to smooth the sides of the cake and off set spatula for the top <sep> place in the fridge for at least 2 to 4 hours so the <unk> is set <sep> place the cake on a <unk> rack with a large <unk> or clean baking tray to <unk> the <unk> <sep> make sure your <unk> is <unk> consistency if not warm it in the microwave for 10 to 20 <unk> <sep> tip – do not <unk> the <unk> you want it to be <unk> consistency but not hot or it will melt the frosting on the cake pour the <unk> on the cake <unk> <unk> in the <unk> and then to the sides making sure you pour <unk> <unk> to cover the <unk> cake <sep> if you have any <unk> <unk> use a spatula to <unk> smooth the sides <sep> <unk> do not use the spatula too much as you will leave <unk> on the cake <sep> the <unk> you <unk> on this at this <unk> the <unk> the <unk> <sep> place the cake in the fridge and let cool completely <sep> <unk> the chocolate <unk> and let cool in the fridge <sep> when the cake is cooled place the <unk> chocolate <unk> in a piping bag and pipe any <unk> you want <sep> i <unk> chopped <unk> to <unk> the cake but you can use <unk> <unk> <sep> use ready <unk> chocolate <unk> <unk> as chocolate <unk> <unk> <unk> <unk> <unk> <sep> <unk> the cake sides with <unk> powder <sep> add chocolate <unk> <unk> <sep> melt some <unk> chocolate and sprinkle it in a <unk> <unk> or just <unk> some <unk> chocolate <end>
#
# Prediction Caption: cream until you have a <unk> bag <sep> <unk> a parchment <unk> for about <unk> if <unk> <unk> <sep> <unk> <sep> spread with powdered sugar salt and combine sugar is almost set the fridge for at least 6 hours or until the cake <unk> the cake will <unk> <sep> wrap <unk> to be <unk> so <unk> <unk> <sep> place it will <unk> if <unk> cream over the <unk> cake on one <unk> and around the batter into the cake tip you should be cool completely pro tip <unk> cake pan by <unk> <sep> pour the frosting in a <unk> bowl for <unk> <end>

# %%
del real_caption, result, attention_plot, image

# %%
import numpy as np

saved_images = np.load("../input/saved-images/saved_images (1).npy")
dataset = tf.data.Dataset.from_tensor_slices({"image":saved_images, "text":text_index}).batch(128)

# %%
for data in dataset.take(1):
    print(data['text'].shape)
    print(data['image'].shape)
# Out:
# (128, 1000)
# (128, 128, 128, 3)

# %%
model = CNNattn(
        vocab_size = vocab_size,
        emb_dim = 64,
        gru_units = 16,
        w_units = 64,
        head_denses_units = [100],
        w = 64,
        h = 64,
        channel = 3,
        n_cov = 2,
        filters_list =[16, 16],
        kernel_sizes = [(8,8), (8,8)],
        n_pool = 2
    )

# %% [markdown]
# Try model forward pass

# %%
for data in dataset.take(1):
    print('image.shape',data['image'].shape)
    print('text.shape',data['text'].shape)

    image = data['image']
    text  = data['text']

    o = model(image, text[:,1], verbose=1)
    break
# Out:
# image.shape (128, 128, 128, 3)
# text.shape (128, 1000)
# input image: (128, 128, 128, 3)
# conv_0 output: (128, 121, 121, 16)
# pool_0 output: (128, 60, 60, 16)
# conv_1 output: (128, 53, 53, 16)
# pool_1 output: (128, 26, 26, 16)
# final output: (128, 676, 16)
# embed output: (128, 1, 64)
# GRU output: (128, 1, 16)
# attention output: (128, 1, 64)
# head_denses output: (128, 1, 100)
# output: (128, 1, 1000)
# output: (128, 1000)

# %% [markdown]
# # 3. Train model

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy')

optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')


def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask

    return tf.reduce_mean(loss_)

# %%
@tf.function
def train_step(image, text, verbose):
    loss = 0
    dec_input = tf.expand_dims([tokenizer.word_index['<start>']] * text.shape[0], 1)

    with tf.GradientTape() as tape:
        print(text.shape[1])
        for i in range(1, text.shape[1]):
            
            print(".", end='')
            # passing the features through the decoder
            predictions = model(image, dec_input, verbose)

            loss += loss_function(text[:, i], predictions)

            # using teacher forcing
            dec_input = text[:, i]

    total_loss = (loss / int(text.shape[1]))

    trainable_variables = model.trainable_variables

    gradients = tape.gradient(loss, trainable_variables)

    optimizer.apply_gradients(zip(gradients, trainable_variables))

    return loss, total_loss

# %%
import time

EPOCHS = 5

for epoch in range(EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, dataset) in enumerate(dataset):
        print(type(dataset))
        image = dataset['image']
        text  = dataset['text']
        batch_loss, t_loss = train_step(image, text, verbose=0)
        total_loss += t_loss

        if batch % 100 == 0:
            average_batch_loss = batch_loss.numpy()/int(text.shape[1])
            print(f'\nEpoch {epoch+1} Batch {batch} Loss {average_batch_loss:.4f}')


    print(f'\nLoss: {total_loss}')

    print(f'Time taken for 1 epoch {time.time()-start:.2f} sec\n')
# Out:
# <class 'dict'>
# 1000
# .......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................

# %%
np.sum([np.prod(v.get_shape().as_list()) for v in model.trainable_variables])
# Out:
# 197101.0

# %%
for i in model.trainable_variables:
    print(i.get_shape().as_list())
# Out:
# [8, 8, 3, 16]
# [16]
# [8, 8, 16, 16]
# [16]
# [1000, 64]
# [64, 48]
# [16, 48]
# [2, 48]
# [16, 64]
# [64]
# [16, 64]
# [64]
# []
# [64, 100]
# [100]
# [100, 1000]
# [1000]

# %%
np.prod((8, 8, 3, 16))
# Out:
# 3072

# %%
# Out:
# 3072

# %%
i=0
for data in dataset:
    print(data['text'])
    i+=1
    print("="*30)
    if i==5:break
# Out:
# tf.Tensor(
# [[ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  ...
#  [ 56 451   1 ...   0   0   0]
#  [ 56 169 532 ...   0   0   0]
#  [ 56 117  46 ...   0   0   0]], shape=(16, 1000), dtype=int32)
# ==============================
# tf.Tensor(
# [[ 56 929  41 ...   0   0   0]
#  [ 56 929  41 ...   0   0   0]
#  [ 56 929  41 ...   0   0   0]
#  ...
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]], shape=(16, 1000), dtype=int32)
# ==============================
# tf.Tensor(
# [[ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  ...
#  [ 56 107   2 ...   0   0   0]
#  [ 56 107   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]], shape=(16, 1000), dtype=int32)
# ==============================
# tf.Tensor(
# [[ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  ...
#  [ 56 117  46 ...   0   0   0]
#  [ 56 242   7 ...   0   0   0]
#  [ 56 242   7 ...   0   0   0]], shape=(16, 1000), dtype=int32)
# ==============================
# tf.Tensor(
# [[ 56 242   7 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  [ 56 117   2 ...   0   0   0]
#  ...
#  [ 56   7   4 ...   0   0   0]
#  [ 56   7   4 ...   0   0   0]
#  [ 56   7   4 ...   0   0   0]], shape=(16, 1000), dtype=int32)
# ==============================

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1
